# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r"C:\Users\acer\OneDrive\AI SALES PROJ\Lenskart India.csv")

print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())

df.head()
# Out:
# Shape: (150000, 14)
#
# Columns:
# ['order_id', 'order_date', 'city', 'state', 'sales_channel', 'store_type', 'product_category', 'quantity', 'unit_price', 'discount_percent', 'net_sales_amount', 'payment_mode', 'customer_gender', 'customer_age']
#      order_id  order_date       city           state sales_channel  \
# 0  ORD1000000  2023-05-17     Bhopal  Madhya Pradesh        Online
# 1  ORD1000001  2022-04-24  Faridabad         Haryana        Online
# 2  ORD1000002  2022-06-05    Kolkata     West Bengal       Offline
# 3  ORD1000003  2024-03-24  Ahmedabad         Gujarat       Offline
# 4  ORD1000004  2024-08-17  Ahmedabad         Gujarat        Online
#
#          store_type  product_category  quantity  unit_price  discount_percent  \
# 0       Online Only        Sunglasses         3        1659                 0
# 1       Online Only  Computer Glasses         1        3891                 0
# 2  Standalone Store    Contact Lenses         3        4243                10
# 3       Online Only        Sunglasses         3        2484                 0
# 4       Online Only    Contact Lenses         2        3232                 0
#
#    net_sales_amount payment_mode customer_gender  customer_age
# 0            4977.0  Net Banking          Female            25
# 1            3891.0  Credit Card          Female            36
# 2           11456.1   Debit Card          Female            41
# 3            7452.0  Credit Card          Female            41
# 4            6464.0   Debit Card           Other            38

# %%
print(df.info())
print(df.columns)
print(df.describe())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   order_id          150000 non-null  str
#  1   order_date        150000 non-null  str
#  2   city              150000 non-null  str
#  3   state             150000 non-null  str
#  4   sales_channel     150000 non-null  str
#  5   store_type        150000 non-null  str
#  6   product_category  150000 non-null  str
#  7   quantity          150000 non-null  int64
#  8   unit_price        150000 non-null  int64
#  9   discount_percent  150000 non-null  int64
#  10  net_sales_amount  150000 non-null  float64
#  11  payment_mode      150000 non-null  str
#  12  customer_gender   150000 non-null  str
#  13  customer_age      150000 non-null  int64
# dtypes: float64(1), int64(4), str(9)
# memory usage: 16.0 MB
# None
# Index(['order_id', 'order_date', 'city', 'state', 'sales_channel',
#        'store_type', 'product_category', 'quantity', 'unit_price',
#        'discount_percent', 'net_sales_amount', 'payment_mode',
#        'customer_gender', 'customer_age'],
#       dtype='str')
#             quantity     unit_price  discount_percent  net_sales_amount  \
# count  150000.000000  150000.000000     150000.000000     150000.000000
# mean        2.000427    2895.170913          9.747933       5229.039933
# std         0.817487    1213.293298          7.144378       3230.046503
# min         1.000000     799.000000          0.000000        599.250000
# 25%         1.000000    1846.000000          5.000000       2707.200000
# 50%         2.000000    2889.000000         10.000000       4290.800000
# 75%         3.000000    3949.000000         15.000000       7366.100000
# max         3.000000    4998.000000         25.000000      14994.000000
#
#         customer_age
# count  150000.000000
# mean       41.098447
# std        13.557980
# min        18.000000
# 25%        29.000000
# 50%        41.000000
# 75%        53.000000
# max        64.000000

# %%
print(df.isnull().sum())
print(df.isnull().sum().sum())
# Out:
# order_id            0
# order_date          0
# city                0
# state               0
# sales_channel       0
# store_type          0
# product_category    0
# quantity            0
# unit_price          0
# discount_percent    0
# net_sales_amount    0
# payment_mode        0
# customer_gender     0
# customer_age        0
# dtype: int64
# 0

# %%
print("Duplicates:", df.duplicated().sum())
# Out:
# Duplicates: 0

# %%
for col in df.columns:
    print("\n", col)
    print(df[col].nunique())
# Out:
#  order_id
# 150000
#
#  order_date
# 1461
#
#  city
# 23
#
#  state
# 16
#
#  sales_channel
# 2
#
#  store_type
# 4
#
#  product_category
# 4
#
#  quantity
# 3
#
#  unit_price
# 4200
#
#  discount_percent
# 6
#
#  net_sales_amount
# 38647
#
#  payment_mode
# 5
#
#  customer_gender
# 3
#
#  customer_age
# 47

# %%
print(df.select_dtypes(include="object").columns)

for col in df.select_dtypes(include="object"):
    print("\n", col)
    print(df[col].value_counts().head(10))
# Out:
# Index(['order_id', 'order_date', 'city', 'state', 'sales_channel',
#        'store_type', 'product_category', 'payment_mode', 'customer_gender'],
#       dtype='str')
#
#  order_id
# order_id
# ORD1000000    1
# ORD1000001    1
# ORD1000002    1
# ORD1000003    1
# ORD1000004    1
# ORD1000005    1
# ORD1000006    1
# ORD1000007    1
# ORD1000008    1
# ORD1000009    1
# Name: count, dtype: int64
#
#  order_date
# C:\Users\acer\AppData\Local\Temp\ipykernel_336\2097546183.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   print(df.select_dtypes(include="object").columns)
# C:\Users\acer\AppData\Local\Temp\ipykernel_336\2097546183.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in df.select_dtypes(include="object"):
# order_date
# 2023-04-23    133
# 2025-04-26    133
# 2025-12-23    132
# 2023-11-15    132
# 2024-04-06    129
# 2023-09-04    129
# 2022-10-26    128
# 2024-06-05    127
# 2025-06-07    127
# 2022-09-28    126
# Name: count, dtype: int64
#
#  city
# city
# Indore         6662
# Hyderabad      6639
# Cuttack        6633
# Kochi          6623
# Patna          6584
# Kolkata        6577
# Trivandrum     6571
# Chennai        6537
# Bhubaneswar    6537
# Delhi          6527
# Name: count, dtype: int64
#
#  state
# state
# Kerala            13194
# Madhya Pradesh    13170
# Odisha            13170
# Maharashtra       13028
# Tamil Nadu        13008
# Uttar Pradesh     12979
# Haryana           12873
# Telangana          6639
# Bihar              6584
# West Bengal        6577
# Name: count, dtype: int64
#
#  sales_channel
# sales_channel
# Online     75190
# Offline    74810
# Name: count, dtype: int64
#
#  store_type
# store_type
# Online Only          93782
# High Street Store    18924
# Standalone Store     18695
# Mall Store           18599
# Name: count, dtype: int64
#
#  product_category
# product_category
# Eyeglasses          37717
# Contact Lenses      37472
# Computer Glasses    37406
# Sunglasses          37405
# Name: count, dtype: int64
#
#  payment_mode
# payment_mode
# Net Banking    30189
# Debit Card     30063
# Credit Card    30033
# Cash           29962
# UPI            29753
# Name: count, dtype: int64
#
#  customer_gender
# customer_gender
# Male      50225
# Female    49931
# Other     49844
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="customer_gender")
plt.title("Customer Gender Distribution")
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['order_id', 'order_date', 'city', 'state', 'sales_channel', 'store_type', 'product_category', 'quantity', 'unit_price', 'discount_percent', 'net_sales_amount', 'payment_mode', 'customer_gender', 'customer_age']

# %%
df["sales"] = df["quantity"] * df["unit_price"]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df["sales"], bins=20)
plt.title("Sales Distribution")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df["quantity"], df["sales"])
plt.xlabel("Quantity")
plt.ylabel("Sales")
plt.title("Quantity vs Sales")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.boxplot(df["sales"])
plt.title("Sales Outlier Detection")
plt.ylabel("Sales")
plt.show()

# %%
Q1 = df["sales"].quantile(0.25)
Q3 = df["sales"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df["sales"] < lower) | (df["sales"] > upper)]

print("Number of Outliers:", len(outliers))
print(outliers.head())
# Out:
# Number of Outliers: 0
# Empty DataFrame
# Columns: [order_id, order_date, city, state, sales_channel, store_type, product_category, quantity, unit_price, discount_percent, net_sales_amount, payment_mode, customer_gender, customer_age, sales]
# Index: []

# %%
import seaborn as sns

numeric_df = df.select_dtypes(include=['int64','float64'])

plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
df.to_csv("cleaned_sales_data.csv", index=False)

print("EDA Completed Successfully")
# Out:
# EDA Completed Successfully
